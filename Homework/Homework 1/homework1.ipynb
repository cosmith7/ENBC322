# %%
# simple function

import math

def hypotenuse_calculator():
    a = float(input("Enter side a: "))
    b = float(input("Enter side b: "))

    print("Hypotenuse of your triangle: ", math.sqrt(a ** 2 + b ** 2))

hypotenuse_calculator()
# Out:
# Hypotenuse of your triangle:  5.0
